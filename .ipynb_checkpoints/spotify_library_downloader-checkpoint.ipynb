# %%
import numpy as np
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# This code downloads one's spotify library for clustering - Code adapted from https://towardsdatascience.com/k-means-clustering-using-spotify-song-features-9eb7d53d105c

# %%
scope = "user-library-read playlist-modify-private"
OAuth = SpotifyOAuth(
        scope=scope,         
        redirect_uri='http://localhost:8888/callback',
        client_id = 'fcef59298f4c44d69828868115e7f13b',
        client_secret = 'f623a77913c74911a3b637f9acbcaf84',
        username= 'kay3rx')

sp = spotipy.Spotify(auth_manager=OAuth)

# %%
offset = 0
songs = []
items = []
ids = []
while True:
    content = sp.current_user_saved_tracks(limit=50, offset=offset)
    songs += content['items']
    if content['next'] is not None:
        offset += 100
    else:
        break
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/3k/3gvdq1311j3dydnh2h601mr00000gn/T/ipykernel_26964/487186050.py in <module>
#       4 ids = []
#       5 while True:
# ----> 6     content = sp.current_user_saved_tracks(limit=50, offset=offset)
#       7     songs += content['items']
#       8     if content['next'] is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/client.py in current_user_saved_tracks(self, limit, offset, market)
#    1230
#    1231         """
# -> 1232         return self._get("me/tracks", limit=limit, offset=offset, market=market)
#    1233
#    1234     def current_user_saved_tracks_add(self, tracks=None):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     295             kwargs.update(args)
#     296
# --> 297         return self._internal_call("GET", url, payload, kwargs)
#     298
#     299     def _post(self, url, args=None, payload=None, **kwargs):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     219         if not url.startswith("http"):
#     220             url = self.prefix + url
# --> 221         headers = self._auth_headers()
#     222
#     223         if "content_type" in args["params"]:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/client.py in _auth_headers(self)
#     210             return {}
#     211         try:
# --> 212             token = self.auth_manager.get_access_token(as_dict=False)
#     213         except TypeError:
#     214             token = self.auth_manager.get_access_token()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/oauth2.py in get_access_token(self, code, as_dict, check_cache)
#     533         payload = {
#     534             "redirect_uri": self.redirect_uri,
# --> 535             "code": code or self.get_auth_response(),
#     536             "grant_type": "authorization_code",
#     537         }
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/oauth2.py in get_auth_response(self, open_browser)
#     488             # Only start a local http server if a port is specified
#     489             if redirect_port:
# --> 490                 return self._get_auth_response_local_server(redirect_port)
#     491             else:
#     492                 logger.warning('Using `%s` as redirect URI without a port. '
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/oauth2.py in _get_auth_response_local_server(self, redirect_port)
#     455
#     456     def _get_auth_response_local_server(self, redirect_port):
# --> 457         server = start_local_http_server(redirect_port)
#     458         self._open_auth_url()
#     459         server.handle_request()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/spotipy/oauth2.py in start_local_http_server(port, handler)
#    1301
#    1302 def start_local_http_server(port, handler=RequestHandler):
# -> 1303     server = HTTPServer(("127.0.0.1", port), handler)
#    1304     server.allow_reuse_address = True
#    1305     server.auth_code = None
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socketserver.py in __init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     450         if bind_and_activate:
#     451             try:
# --> 452                 self.server_bind()
#     453                 self.server_activate()
#     454             except:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/server.py in server_bind(self)
#     136     def server_bind(self):
#     137         """Override server_bind to store the server name."""
# --> 138         socketserver.TCPServer.server_bind(self)
#     139         host, port = self.server_address[:2]
#     140         self.server_name = socket.getfqdn(host)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socketserver.py in server_bind(self)
#     464         if self.allow_reuse_address:
#     465             self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 466         self.socket.bind(self.server_address)
#     467         self.server_address = self.socket.getsockname()
#     468
#
# OSError: [Errno 48] Address already in use

# %%
# sample song
songs[0]
len(songs)
# Out:
# 746

# %%
song_names = []
artist_names = []
audio_features = []
index = 0
for i in songs:
    song_names.append(i['track']['name'])
    artist_names.append(i['track']['artists'][0]['name'])
    ids.append(i['track']['id'])
while index < len(ids):
    audio_features += sp.audio_features(ids[index:index + 50])
    index += 50
    
features_list = []
for features in audio_features:
    features_list.append([features['danceability'], features['energy'],
                          features['key'],features['loudness'],
                          features['mode'], features['speechiness'],
                          features['acousticness'],features['instrumentalness'],
                          features['liveness'], features['valence'],
                          features['tempo'],features['duration_ms'],
                          features['time_signature'], features['type'],
                          features['uri']])

df = pd.DataFrame(features_list, columns= ["danceability", "energy", "key", "loudness", "mode",
             "speechiness", "acousticness", "instrumentalness",
             "liveness", "valence", "tempo", "duration_ms", "time_signature", "type", "uri"])

# %%
df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.700   0.392    9    -8.911     1       0.0330       0.05780
# 1           0.667   0.719    7    -5.371     0       0.0346       0.00285
# 2           0.536   0.659    6    -9.732     1       0.0483       0.40600
# 3           0.577   0.797    2    -5.039     1       0.0366       0.09690
# 4           0.603   0.691    5    -5.805     1       0.0372       0.02480
# ..            ...     ...  ...       ...   ...          ...           ...
# 741         0.463   0.715    1    -5.111     1       0.0304       0.03980
# 742         0.359   0.649    3    -7.060     1       0.0349       0.10700
# 743         0.672   0.901    2    -2.415     1       0.0353       0.05450
# 744         0.535   0.574    2    -6.865     0       0.0372       0.35000
# 745         0.691   0.631    2    -6.478     1       0.0368       0.04830
#
#      instrumentalness  liveness  valence    tempo  duration_ms  \
# 0            0.000000    0.0802    0.250  103.044       189907
# 1            0.000081    0.0736    0.717  100.021       237520
# 2            0.004000    0.1070    0.199  170.035       171020
# 3            0.076600    0.3110    0.427  127.995       319400
# 4            0.000000    0.5830    0.577  147.148       172267
# ..                ...       ...      ...      ...          ...
# 741          0.000004    0.1260    0.335  173.854       191267
# 742          0.012400    0.0555    0.133  111.709       278373
# 743          0.000285    0.0792    0.507   99.989       194000
# 744          0.000100    0.1200    0.445   84.984       273424
# 745          0.000011    0.1040    0.800   92.004       161124
#
#      time_signature            type                                   uri
# 0                 4  audio_features  spotify:track:0s26En1JoJhVj32vizElpA
# 1                 4  audio_features  spotify:track:7szuecWAPwGoV1e5vGu8tl
# 2                 4  audio_features  spotify:track:38umMmZQdeoOG7Zojor4g3
# 3                 4  audio_features  spotify:track:1NId6BKUZwaLDKgZXXZuGC
# 4                 4  audio_features  spotify:track:0U1W2LZVUX7qTm7dDpqxh6
# ..              ...             ...                                   ...
# 741               4  audio_features  spotify:track:3KMImfwJj3KXa6M3QRYsqH
# 742               4  audio_features  spotify:track:5g7rJvWYVrloJZwKiShqlS
# 743               4  audio_features  spotify:track:5k31cAfP8yymw8v0AYQIjr
# 744               4  audio_features  spotify:track:49h0RYK3yzWkfbVyNJjJ01
# 745               4  audio_features  spotify:track:2v8X6L6j0kbUPXDZwtXvXU
#
# [746 rows x 15 columns]

# %%
print(len(song_names), len(artist_names))
print(song_names[0:10])
print(artist_names[0:10])
# Out:
# 746 746
# ['Feelings', 'In Your Eyes', 'ANGOSTURA', 'Pretty Places', "When You're Gone", 'TOUCH', 'hate to be lame (feat. FINNEAS)', 'erase me (feat. Jacob Collier)', 'circle the drain', 'Take Me']
# ['Lauv', 'The Weeknd', 'keshi', 'Aly & AJ', 'Shawn Mendes', 'keshi', 'Lizzy McAlpine', 'Lizzy McAlpine', 'Soccer Mommy', 'Aly & AJ']

# %%
df['name'] = song_names
df['artists'] = [["'" + i + "'"] for i in artist_names]

# %%
#df
df.to_csv('tracks_features_qx.csv')
